# %% [markdown]
# # Import lib

# %%
import pandas as pd
import numpy as np
import cv2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input,Dense,Flatten,Conv2D,BatchNormalization,MaxPooling2D,Dropout, Add
from tensorflow.keras.models import Model

# useful for getting number of output classes
from glob import glob

import matplotlib.pyplot as plt
from matplotlib import image
from PIL import Image

# %% [markdown]
# # Split

# %%
import splitfolders

# Split with any ratio in train, val, test set
# we do not split it in validation set since the dataset is quite small and we are not doing any hyperparameter tuning
splitfolders.ratio("archive/Method2", output="archive/Method2_split",
    seed=1337, ratio=(0.8, 0, 0.2), group_prefix=None, move=False)
# Out:
# Copying files: 3662 files [00:25, 145.98 files/s]

# %% [markdown]
# # Dataset

# %%
train_path = 'archive/Method2_split/train'
test_path = 'archive/Method2_split/test'

# %%
classes = glob('archive/Method2_split/train/*')

# %%
classes
# Out:
# ['archive/Method2_split/train\\Mild',
#  'archive/Method2_split/train\\Moderate',
#  'archive/Method2_split/train\\No_DR',
#  'archive/Method2_split/train\\Proliferate_DR',
#  'archive/Method2_split/train\\Severe']

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 10,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   vertical_flip=True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 64,
                                                 class_mode = 'categorical')
# Out:
# Found 2929 images belonging to 5 classes.

# %%
test_set = test_datagen.flow_from_directory(test_path,
                                           target_size = (224, 224),
                                           batch_size = 64,
                                           class_mode = 'categorical')
# Out:
# Found 733 images belonging to 5 classes.

# %% [markdown]
# # Model

# %%
# Define the model parameters using functional api

inputs = Input(shape=(224,224,3))
cnn1 = Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu')(inputs)
bnor1 = BatchNormalization()(cnn1)
max1 = MaxPooling2D(pool_size=(2,2))(bnor1)

cnn2 = Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same")(max1)
bnor2 = BatchNormalization()(cnn2)
max2 = MaxPooling2D(pool_size=(3,3))(bnor2)


cnn3 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same")(max2)
bnor3 = BatchNormalization()(cnn3)

cnn4 = Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same")(bnor3)
bnor4 = BatchNormalization()(cnn4)

cnn5 = Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same")(bnor4)
add = Add()([cnn5,cnn3])
bnor5 = BatchNormalization()(add)

cnn6 = Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same")(bnor5)
bnor6 = BatchNormalization()(cnn6)

cnn7 = Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same")(bnor6)
add1 = Add()([cnn7,bnor5,cnn3])
bnor7 = BatchNormalization()(add1)
max3 = MaxPooling2D(pool_size=(2,2))(bnor7)

flat = Flatten()(max3)
dense1  = Dense(1024, activation = 'relu')(flat)
drop1 = Dropout(0.5)(dense1)
dense2 = Dense(1024, activation = 'relu')(drop1)
add2 = Add()([dense2,dense1])
dense3 = Dense(1024, activation = 'relu')(add2)
add3 = Add()([dense3,dense1])
drop2 = Dropout(0.5)(add3)
outputs = Dense(5, activation = 'softmax')(drop2)

# %%
model = Model(inputs=inputs, outputs=outputs, name='UGP_model') # defining the model

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = Adam(learning_rate=0.001),
    metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "UGP_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 54, 54, 128)  46592       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 54, 54, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 27, 27, 128)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 256)  819456      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 9, 9, 256)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 9, 9, 256)    590080      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 9, 9, 256)    1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 9, 9, 256)    65792       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 9, 9, 256)    1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 256)    65792       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 9, 9, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 9, 9, 256)    1024        add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 256)    65792       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 9, 9, 256)    1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 9, 9, 256)    65792       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 9, 9, 256)    0           conv2d_6[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 9, 9, 256)    1024        add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         4195328     flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1049600     dropout[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1024)         0           dense_1[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         1049600     add_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1024)         0           dense_2[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           add_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            5125        dropout_1[0][0]
# ==================================================================================================
# Total params: 8,025,605
# Trainable params: 8,022,277
# Non-trainable params: 3,328
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True,to_file='double.png')

# %%
r = model.fit(
    training_set,
    epochs = 50,
    steps_per_epoch=len(training_set),
)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 58s 1s/step - loss: 2.8534 - accuracy: 0.5166
# Epoch 2/50
# 46/46 [==============================] - 32s 702ms/step - loss: 1.0502 - accuracy: 0.6333
# Epoch 3/50
# 46/46 [==============================] - 29s 628ms/step - loss: 0.9783 - accuracy: 0.6480
# Epoch 4/50
# 46/46 [==============================] - 29s 631ms/step - loss: 0.9310 - accuracy: 0.6729
# Epoch 5/50
# 46/46 [==============================] - 29s 625ms/step - loss: 0.9072 - accuracy: 0.6849
# Epoch 6/50
# 46/46 [==============================] - 31s 661ms/step - loss: 0.9039 - accuracy: 0.6859
# Epoch 7/50
# 46/46 [==============================] - 30s 646ms/step - loss: 0.8773 - accuracy: 0.6907
# Epoch 8/50
# 46/46 [==============================] - 30s 648ms/step - loss: 0.8697 - accuracy: 0.6917
# Epoch 9/50
# 46/46 [==============================] - 29s 629ms/step - loss: 0.8587 - accuracy: 0.6992
# Epoch 10/50
# 46/46 [==============================] - 29s 631ms/step - loss: 0.8768 - accuracy: 0.6893
# Epoch 11/50
# 46/46 [==============================] - 29s 630ms/step - loss: 0.8376 - accuracy: 0.7078
# Epoch 12/50
# 46/46 [==============================] - 29s 634ms/step - loss: 0.8297 - accuracy: 0.7105
# Epoch 13/50
# 46/46 [==============================] - 29s 628ms/step - loss: 0.8471 - accuracy: 0.6982
# Epoch 14/50
# 46/46 [==============================] - 31s 681ms/step - loss: 0.8270 - accuracy: 0.7037
# Epoch 15/50
# 46/46 [==============================] - 29s 635ms/step - loss: 0.8192 - accuracy: 0.7081
# Epoch 16/50
# 46/46 [==============================] - 30s 641ms/step - loss: 0.8166 - accuracy: 0.7030
# Epoch 17/50
# 46/46 [==============================] - 30s 640ms/step - loss: 0.7839 - accuracy: 0.7183
# Epoch 18/50
# 46/46 [==============================] - 29s 638ms/step - loss: 0.7843 - accuracy: 0.7122
# Epoch 19/50
# 46/46 [==============================] - 30s 653ms/step - loss: 0.7773 - accuracy: 0.7142
# Epoch 20/50
# 46/46 [==============================] - 30s 643ms/step - loss: 0.7711 - accuracy: 0.7139
# Epoch 21/50
# 46/46 [==============================] - 31s 662ms/step - loss: 0.7798 - accuracy: 0.7108
# Epoch 22/50
# 46/46 [==============================] - 31s 674ms/step - loss: 0.7503 - accuracy: 0.7255
# Epoch 23/50
# 46/46 [==============================] - 30s 653ms/step - loss: 0.7530 - accuracy: 0.7231
# Epoch 24/50
# 46/46 [==============================] - 31s 678ms/step - loss: 0.7413 - accuracy: 0.7293
# Epoch 25/50
# 46/46 [==============================] - 32s 693ms/step - loss: 0.7409 - accuracy: 0.7258
# Epoch 26/50
# 46/46 [==============================] - 31s 668ms/step - loss: 0.7375 - accuracy: 0.7279
# Epoch 27/50
# 46/46 [==============================] - 31s 663ms/step - loss: 0.7297 - accuracy: 0.7265
# Epoch 28/50
# 46/46 [==============================] - 31s 664ms/step - loss: 0.7276 - accuracy: 0.7364
# Epoch 29/50
# 46/46 [==============================] - 31s 665ms/step - loss: 0.7093 - accuracy: 0.7368
# Epoch 30/50
# 46/46 [==============================] - 30s 659ms/step - loss: 0.6984 - accuracy: 0.7364
# Epoch 31/50
# 46/46 [==============================] - 31s 664ms/step - loss: 0.6888 - accuracy: 0.7436
# Epoch 32/50
# 46/46 [==============================] - 31s 662ms/step - loss: 0.7007 - accuracy: 0.7354
# Epoch 33/50
# 46/46 [==============================] - 31s 670ms/step - loss: 0.6927 - accuracy: 0.7446
# Epoch 34/50
# 46/46 [==============================] - 31s 672ms/step - loss: 0.6752 - accuracy: 0.7504
# Epoch 35/50
# 46/46 [==============================] - 31s 671ms/step - loss: 0.7094 - accuracy: 0.7378
# Epoch 36/50
# 46/46 [==============================] - 31s 674ms/step - loss: 0.6734 - accuracy: 0.7515
# Epoch 37/50
# 46/46 [==============================] - 32s 695ms/step - loss: 0.6590 - accuracy: 0.7648
# Epoch 38/50
# 46/46 [==============================] - 31s 667ms/step - loss: 0.6615 - accuracy: 0.7545
# Epoch 39/50
# 46/46 [==============================] - 31s 674ms/step - loss: 0.6504 - accuracy: 0.7566
# Epoch 40/50
# 46/46 [==============================] - 31s 682ms/step - loss: 0.6360 - accuracy: 0.7596
# Epoch 41/50
# 46/46 [==============================] - 33s 705ms/step - loss: 0.6337 - accuracy: 0.7600
# Epoch 42/50
# 46/46 [==============================] - 31s 677ms/step - loss: 0.6377 - accuracy: 0.7593
# Epoch 43/50
# 46/46 [==============================] - 31s 682ms/step - loss: 0.6393 - accuracy: 0.7614
# Epoch 44/50
# 46/46 [==============================] - 38s 831ms/step - loss: 0.6516 - accuracy: 0.7555
# Epoch 45/50
# 46/46 [==============================] - 45s 971ms/step - loss: 0.6224 - accuracy: 0.7699
# Epoch 46/50
# 46/46 [==============================] - 44s 955ms/step - loss: 0.6363 - accuracy: 0.7699
# Epoch 47/50
# 46/46 [==============================] - 42s 907ms/step - loss: 0.6482 - accuracy: 0.7617
# Epoch 48/50
# 46/46 [==============================] - 37s 790ms/step - loss: 0.6178 - accuracy: 0.7774
# Epoch 49/50
# 46/46 [==============================] - 40s 861ms/step - loss: 0.6439 - accuracy: 0.7586
# Epoch 50/50
# 46/46 [==============================] - 35s 767ms/step - loss: 0.6051 - accuracy: 0.7723

# %%
# Method 2
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 12/12 [==============================] - 4s 329ms/step - loss: 1.6618 - accuracy: 0.4829
# test loss, test acc: [1.6617947816848755, 0.4829467833042145]

# %%
# CLACHE
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 12/12 [==============================] - 4s 335ms/step - loss: 0.8241 - accuracy: 0.6930
# test loss, test acc: [0.8241429924964905, 0.6930422782897949]

# %%
# HE
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 12/12 [==============================] - 2s 131ms/step - loss: 3.3176 - accuracy: 0.4120
# test loss, test acc: [3.3175735473632812, 0.4120054543018341]

# %%
# Original
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 12/12 [==============================] - 7s 574ms/step - loss: 0.6871 - accuracy: 0.7408
# test loss, test acc: [0.6870625615119934, 0.7407912611961365]

# %%
# Method 1
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 12/12 [==============================] - 4s 327ms/step - loss: 0.9330 - accuracy: 0.7135
# test loss, test acc: [0.9330450892448425, 0.7135061621665955]

# %%
# plot the loss
plt.plot(r.history['loss'], label='train loss')
# plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
# plt.plot(r.history['val_accuracy'], label='test acc')
plt.legend()
plt.show()
