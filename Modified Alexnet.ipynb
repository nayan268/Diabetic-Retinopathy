# %% [markdown]
# # Import lib

# %%
import pandas as pd
import numpy as np
import cv2

import tensorflow
from tensorflow import keras

# useful for getting number of output classes
from glob import glob

import matplotlib.pyplot as plt
from matplotlib import image
from PIL import Image

# %% [markdown]
# # Dataset

# %%
train_path = 'archive/new_dataset/train'
test_path = 'archive/new_dataset/test'

# %%
classes = glob('archive/new_dataset/train/*')

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 15,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   vertical_flip=True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 64,
                                                 class_mode = 'categorical')
# Out:
# Found 2929 images belonging to 5 classes.

# %%
test_set = test_datagen.flow_from_directory(test_path,
                                           target_size = (224, 224),
                                           batch_size = 64,
                                           class_mode = 'categorical')
# Out:
# Found 733 images belonging to 5 classes.

# %% [markdown]
# # Modified AlexNet

# %%
# modified Alexnet as given in the paper 
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(224,224,3)),
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(512,activation='relu'),
    keras.layers.Dense(5,activation='softmax')    
])

# %%
# compling the model with loss, optimiser and metrics
model.compile(
    loss='categorical_crossentropy', 
    optimizer=tensorflow.optimizers.SGD(learning_rate=0.001), 
    metrics=['accuracy']    
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 21632)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               11076096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 11,107,301
# Trainable params: 11,107,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# using test set in place of val set 
# val loss and accuracy is test loss and accuracy
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set),
)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 65s 1s/step - loss: 1.3042 - accuracy: 0.4858 - val_loss: 1.2234 - val_accuracy: 0.4925
# Epoch 2/50
# 46/46 [==============================] - 35s 747ms/step - loss: 1.2221 - accuracy: 0.4981 - val_loss: 1.1377 - val_accuracy: 0.5975
# Epoch 3/50
# 46/46 [==============================] - 35s 761ms/step - loss: 1.1830 - accuracy: 0.5241 - val_loss: 1.1577 - val_accuracy: 0.4925
# Epoch 4/50
# 46/46 [==============================] - 35s 758ms/step - loss: 1.1688 - accuracy: 0.5306 - val_loss: 1.0681 - val_accuracy: 0.6726
# Epoch 5/50
# 46/46 [==============================] - 35s 758ms/step - loss: 1.1472 - accuracy: 0.5381 - val_loss: 1.0741 - val_accuracy: 0.5020
# Epoch 6/50
# 46/46 [==============================] - 35s 766ms/step - loss: 1.1192 - accuracy: 0.5640 - val_loss: 1.0193 - val_accuracy: 0.5553
# Epoch 7/50
# 46/46 [==============================] - 35s 763ms/step - loss: 1.0884 - accuracy: 0.5784 - val_loss: 1.0305 - val_accuracy: 0.5362
# Epoch 8/50
# 46/46 [==============================] - 36s 769ms/step - loss: 1.0745 - accuracy: 0.5930 - val_loss: 0.9644 - val_accuracy: 0.6494
# Epoch 9/50
# 46/46 [==============================] - 36s 771ms/step - loss: 1.0641 - accuracy: 0.5999 - val_loss: 1.0847 - val_accuracy: 0.5007
# Epoch 10/50
# 46/46 [==============================] - 35s 766ms/step - loss: 1.0780 - accuracy: 0.5859 - val_loss: 0.9423 - val_accuracy: 0.6617
# Epoch 11/50
# 46/46 [==============================] - 36s 769ms/step - loss: 1.0360 - accuracy: 0.6060 - val_loss: 0.9371 - val_accuracy: 0.6876
# Epoch 12/50
# 46/46 [==============================] - 35s 766ms/step - loss: 1.0503 - accuracy: 0.6019 - val_loss: 0.9191 - val_accuracy: 0.6780
# Epoch 13/50
# 46/46 [==============================] - 35s 759ms/step - loss: 1.0162 - accuracy: 0.6275 - val_loss: 0.9040 - val_accuracy: 0.6658
# Epoch 14/50
# 46/46 [==============================] - 36s 770ms/step - loss: 1.0129 - accuracy: 0.6272 - val_loss: 0.9084 - val_accuracy: 0.6698
# Epoch 15/50
# 46/46 [==============================] - 35s 766ms/step - loss: 1.0114 - accuracy: 0.6262 - val_loss: 0.9127 - val_accuracy: 0.6780
# Epoch 16/50
# 46/46 [==============================] - 36s 771ms/step - loss: 0.9916 - accuracy: 0.6279 - val_loss: 0.9119 - val_accuracy: 0.6862
# Epoch 17/50
# 46/46 [==============================] - 35s 759ms/step - loss: 0.9875 - accuracy: 0.6422 - val_loss: 0.8928 - val_accuracy: 0.6712
# Epoch 18/50
# 46/46 [==============================] - 35s 762ms/step - loss: 0.9852 - accuracy: 0.6398 - val_loss: 0.8761 - val_accuracy: 0.6835
# Epoch 19/50
# 46/46 [==============================] - 35s 764ms/step - loss: 0.9665 - accuracy: 0.6429 - val_loss: 0.9179 - val_accuracy: 0.6671
# Epoch 20/50
# 46/46 [==============================] - 35s 766ms/step - loss: 0.9662 - accuracy: 0.6456 - val_loss: 0.8716 - val_accuracy: 0.6917
# Epoch 21/50
# 46/46 [==============================] - 35s 765ms/step - loss: 0.9634 - accuracy: 0.6357 - val_loss: 0.8535 - val_accuracy: 0.7012
# Epoch 22/50
# 46/46 [==============================] - 35s 755ms/step - loss: 0.9339 - accuracy: 0.6675 - val_loss: 0.8459 - val_accuracy: 0.6876
# Epoch 23/50
# 46/46 [==============================] - 35s 760ms/step - loss: 0.9288 - accuracy: 0.6559 - val_loss: 0.8306 - val_accuracy: 0.6971
# Epoch 24/50
# 46/46 [==============================] - 35s 762ms/step - loss: 0.9426 - accuracy: 0.6623 - val_loss: 0.8507 - val_accuracy: 0.6821
# Epoch 25/50
# 46/46 [==============================] - 35s 762ms/step - loss: 0.9157 - accuracy: 0.6681 - val_loss: 0.8171 - val_accuracy: 0.6999
# Epoch 26/50
# 46/46 [==============================] - 35s 759ms/step - loss: 0.9093 - accuracy: 0.6688 - val_loss: 0.8521 - val_accuracy: 0.6917
# Epoch 27/50
# 46/46 [==============================] - 35s 756ms/step - loss: 0.9252 - accuracy: 0.6637 - val_loss: 0.8220 - val_accuracy: 0.7162
# Epoch 28/50
# 46/46 [==============================] - 35s 764ms/step - loss: 0.8996 - accuracy: 0.6760 - val_loss: 0.8533 - val_accuracy: 0.6930
# Epoch 29/50
# 46/46 [==============================] - 35s 765ms/step - loss: 0.9094 - accuracy: 0.6726 - val_loss: 0.8366 - val_accuracy: 0.7135
# Epoch 30/50
# 46/46 [==============================] - 35s 761ms/step - loss: 0.9053 - accuracy: 0.6705 - val_loss: 0.8661 - val_accuracy: 0.6889
# Epoch 31/50
# 46/46 [==============================] - 36s 771ms/step - loss: 0.8867 - accuracy: 0.6791 - val_loss: 0.8072 - val_accuracy: 0.7067
# Epoch 32/50
# 46/46 [==============================] - 35s 764ms/step - loss: 0.8967 - accuracy: 0.6774 - val_loss: 0.8380 - val_accuracy: 0.6903
# Epoch 33/50
# 46/46 [==============================] - 35s 761ms/step - loss: 0.8804 - accuracy: 0.6839 - val_loss: 0.8215 - val_accuracy: 0.7026
# Epoch 34/50
# 46/46 [==============================] - 35s 763ms/step - loss: 0.8791 - accuracy: 0.6845 - val_loss: 0.8098 - val_accuracy: 0.7040
# Epoch 35/50
# 46/46 [==============================] - 35s 764ms/step - loss: 0.8716 - accuracy: 0.6873 - val_loss: 0.8192 - val_accuracy: 0.7135
# Epoch 36/50
# 46/46 [==============================] - 35s 761ms/step - loss: 0.8596 - accuracy: 0.6897 - val_loss: 0.8060 - val_accuracy: 0.7190
# Epoch 37/50
# 46/46 [==============================] - 35s 757ms/step - loss: 0.8654 - accuracy: 0.6914 - val_loss: 0.8156 - val_accuracy: 0.7176
# Epoch 38/50
# 46/46 [==============================] - 35s 755ms/step - loss: 0.8569 - accuracy: 0.6903 - val_loss: 0.8106 - val_accuracy: 0.7040
# Epoch 39/50
# 46/46 [==============================] - 35s 759ms/step - loss: 0.8498 - accuracy: 0.6927 - val_loss: 0.8660 - val_accuracy: 0.6876
# Epoch 40/50
# 46/46 [==============================] - 35s 762ms/step - loss: 0.8555 - accuracy: 0.6917 - val_loss: 0.8293 - val_accuracy: 0.7012
# Epoch 41/50
# 46/46 [==============================] - 35s 755ms/step - loss: 0.8533 - accuracy: 0.6903 - val_loss: 0.8303 - val_accuracy: 0.6930
# Epoch 42/50
# 46/46 [==============================] - 35s 754ms/step - loss: 0.8465 - accuracy: 0.6992 - val_loss: 0.8127 - val_accuracy: 0.7053
# Epoch 43/50
# 46/46 [==============================] - 36s 779ms/step - loss: 0.8366 - accuracy: 0.6989 - val_loss: 0.8051 - val_accuracy: 0.7053
# Epoch 44/50
# 46/46 [==============================] - 38s 826ms/step - loss: 0.8374 - accuracy: 0.7016 - val_loss: 0.7811 - val_accuracy: 0.7067
# Epoch 45/50
# 46/46 [==============================] - 36s 770ms/step - loss: 0.8296 - accuracy: 0.7074 - val_loss: 0.8066 - val_accuracy: 0.7162
# Epoch 46/50
# 46/46 [==============================] - 35s 768ms/step - loss: 0.8176 - accuracy: 0.7071 - val_loss: 0.7995 - val_accuracy: 0.7231
# Epoch 47/50
# 46/46 [==============================] - 35s 768ms/step - loss: 0.8427 - accuracy: 0.7019 - val_loss: 0.7999 - val_accuracy: 0.7135
# Epoch 48/50
# 46/46 [==============================] - 38s 818ms/step - loss: 0.8264 - accuracy: 0.7009 - val_loss: 0.7995 - val_accuracy: 0.7176
# Epoch 49/50
# 46/46 [==============================] - 42s 915ms/step - loss: 0.8059 - accuracy: 0.7098 - val_loss: 0.7938 - val_accuracy: 0.7080
# Epoch 50/50
# 46/46 [==============================] - 44s 955ms/step - loss: 0.8192 - accuracy: 0.7040 - val_loss: 0.7937 - val_accuracy: 0.7121

# %%
#old dataset
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='test acc')
plt.legend()
plt.show()

# %%
#new dataset
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='test acc')
plt.legend()
plt.show()
